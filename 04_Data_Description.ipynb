# %%
import pandas as pd

# %%
# uploading all four wells
well_1 = pd.read_csv('1S-1X log.csv')
well_2 = pd.read_csv('1S-2X log.csv')
well_3 = pd.read_csv('1S-3X log.csv')
well_4 = pd.read_csv('1S-4X log.csv')

# %% [markdown]
# ## 1S-1X log

# %%
#description of well
well_1 = well_1[(well_1 >= 0).all(axis=1)]
well_1.describe()
# Out:
#               DEPTH          CALI            GR           ILD           ITT  \
# count  13857.000000  13857.000000  13857.000000  13857.000000  13857.000000
# mean    2579.827200     12.461762     85.620961      2.660886      0.094735
# std      609.648109      2.105861     24.966066      1.878579      0.015297
# min     1524.000000      8.643100     28.004200      0.581700      0.057300
# 25%     2051.913600     10.922300     60.634600      1.759500      0.085700
# 50%     2579.827200     12.052200     96.696800      2.264600      0.090700
# 75%     3107.740800     13.683300    106.554800      3.009100      0.096600
# max     3635.654400     20.282900    131.366500     44.374600      0.180500
#
#                 LLD           LLS          MSFL          NPHI          RHOB  \
# count  13857.000000  13857.000000  13857.000000  13857.000000  13857.000000
# mean       2.743542      3.001107      2.898048      0.253313      2.419372
# ...

# %% [markdown]
# ## 1S-2x log

# %%
#description of all wells
well_2 = well_2[(well_2 >= 0).all(axis=1)]
well_2.describe()
# Out:
#               DEPTH          CALI            GR           ILD           ITT  \
# count  11320.000000  11320.000000  11320.000000  11320.000000  11320.000000
# mean    2444.429453     14.081408     85.234323      2.296065      0.097496
# std      498.050763      1.370597     26.549183      1.471030      0.015654
# min     1581.912000     10.635300     27.026300      0.661800      0.044500
# 25%     2013.165900     13.220375     60.002875      1.523875      0.088000
# 50%     2444.419800     13.905450     88.443450      1.959200      0.093300
# 75%     2875.673700     14.778525    110.793500      2.560250      0.102100
# max     3307.080000     21.298200    155.178200     34.885400      0.182400
#
#                 LLD           LLS          MSFL          NPHI          RHOB  \
# count  11320.000000  11320.000000  11320.000000  11320.000000  11320.000000
# mean       2.525044      2.707475      2.564374      0.282757      2.484488
# ...

# %% [markdown]
# ## 1S-3X log

# %%
#description of well
well_3 = well_3[(well_3 >= 0).all(axis=1)]
well_3.describe()
# Out:
#              DEPTH         CALI           GR          ILD          ITT  \
# count  7317.000000  7317.000000  7317.000000  7317.000000  7317.000000
# mean   2172.919200    14.607855    73.139227     2.213623     0.106659
# std     321.926757     2.128447    18.097652     1.848817     0.016768
# min    1615.440000    10.557400    28.829100     0.626600     0.040700
# 25%    1894.179600    13.096300    58.027200     1.135300     0.096200
# 50%    2172.919200    14.218500    71.465900     1.532800     0.102600
# 75%    2451.658800    15.547600    89.526900     2.548100     0.121700
# max    2730.398400    20.249800   208.877700    13.630900     0.153300
#
#                LLD          LLS         MSFL         NPHI         RHOB  \
# count  7317.000000  7317.000000  7317.000000  7317.000000  7317.000000
# mean      2.545183     2.565840     3.217575     0.336409     2.384914
# std       3.639349     3.779938     9.538580     0.085419     0.119488
# ...

# %% [markdown]
# ## 1S-4X log

# %%
#description of well
well_4 = well_4[(well_4 >= -115).all(axis=1)]
well_4.describe()
# Out:
#              DEPTH         CALI           GR          ILD          ITT  \
# count  4207.000000  4207.000000  4207.000000  4207.000000  4207.000000
# mean   1718.310000    15.071026    47.986460     2.544955     0.114631
# std     185.105135     2.994140     8.063922     4.088741     0.022000
# min    1397.812800    10.336300    22.782900     0.583200     0.039400
# 25%    1558.061400    12.357350    42.987350     0.893400     0.095700
# 50%    1718.310000    14.939300    48.203600     1.078300     0.118800
# 75%    1878.558600    16.434800    52.675250     2.797100     0.127000
# max    2038.807200    23.877700   123.168500    35.071500     0.203700
#
#                LLD          LLS         MSFL         NPHI         RHOB  \
# count  4207.000000  4207.000000  4207.000000  4207.000000  4207.000000
# mean      3.043719     2.838820     2.789418     0.383056     2.299539
# std       5.818686     5.229001     5.790811     0.105963     0.161439
# ...

# %% [markdown]
# ## END OF CODE
